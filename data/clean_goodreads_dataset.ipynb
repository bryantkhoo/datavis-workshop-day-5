# %%
import pandas as pd

df = pd.read_csv('./books.csv')

# %%
df.shape
# Out:
# (13719, 10)

# %%
df.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       3  Harry Potter and the Sorcerer's Stone (Harry P...
# 3       4  Harry Potter and the Chamber of Secrets (Harry...
# 4       5  Harry Potter and the Prisoner of Azkaban (Harr...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling-Mary GrandPré            4.56  0439785960  9780439785969
# 1  J.K. Rowling-Mary GrandPré            4.49  0439358078  9780439358071
# 2  J.K. Rowling-Mary GrandPré            4.47  0439554934  9780439554930
# 3                J.K. Rowling            4.41  0439554896  9780439554893
# 4  J.K. Rowling-Mary GrandPré            4.55  043965548X  9780439655484
#
#   language_code  # num_pages  ratings_count  text_reviews_count
# 0           eng          652        1944099               26249
# ...

# %%
df = df.sort_values('ratings_count',ascending = False)

# %%
df.head(1000)
# Out:
#        bookID                                              title  \
# 2           3  Harry Potter and the Sorcerer's Stone (Harry P...
# 12248   41865                            Twilight (Twilight  #1)
# 2000     5907                 The Hobbit or There and Back Again
# 1717     5107                             The Catcher in the Rye
# 340       960               Angels & Demons (Robert Langdon  #1)
# ...       ...                                                ...
# 6577    19675          Executive Orders (Jack Ryan Universe  #9)
# 12587   43326                                Tell Me Your Dreams
# 8014    24983             Doomsday Book (Oxford Time Travel  #1)
# 12504   42933                           Tai-Pan (Asian Saga  #2)
# 5237    15676                                          Strangers
#
#                           authors  average_rating        isbn         isbn13  \
# 2      J.K. Rowling-Mary GrandPré            4.47  0439554934  9780439554930
# ...

# %%
top_500 = df[:500]

# %%
top_500.head(500)
# Out:
#        bookID                                              title  \
# 2           3  Harry Potter and the Sorcerer's Stone (Harry P...
# 12248   41865                            Twilight (Twilight  #1)
# 2000     5907                 The Hobbit or There and Back Again
# 1717     5107                             The Catcher in the Rye
# 340       960               Angels & Demons (Robert Langdon  #1)
# ...       ...                                                ...
# 10321   33456                      A Dirty Job (Grim Reaper  #1)
# 1783     5246                                        Ethan Frome
# 5921    17683                  Dead Beat (The Dresden Files  #7)
# 13688   47624                              Lirael (Abhorsen  #2)
# 4099    12505                                          The Idiot
#
#                                                  authors  average_rating  \
# 2                             J.K. Rowling-Mary GrandPré            4.47
# ...

# %%
df.to_csv('500_most_rated_books.csv')
